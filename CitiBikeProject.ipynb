# %% [markdown]
# # _Introduction_
#
#
# Import data from citi bike portal for all the stations
#
# The data could have been downloaded from links directly, but I downloaded the zip file as i noticed some discripencies in the file where there were more than on csv (one of them was dated).
#
# downloaded all the zip files for over 3 years to explore the usage before and after covid.
# 2019 : 12 months
# 2020 : 12 months ( April 2020 - covid)
# 2021 : 12 months
# 2022 : 02 months

# %%
import pandas as pd
from pandas import to_datetime
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import zipfile

# %% [markdown]
# 2020

# %%
df_202001 = pd.read_csv("data\\202001-citibike-tripdata.csv.zip")
df_202002 = pd.read_csv("data\\202002-citibike-tripdata.csv.zip")
df_202003 = pd.read_csv("data\\202003-citibike-tripdata.csv.zip")
df_202004 = pd.read_csv("data\\202004-citibike-tripdata.csv.zip")

# %%
df_202005 = pd.read_csv("data\\202005-citibike-tripdata.csv.zip")
df_202006 = pd.read_csv("data\\202006-citibike-tripdata.csv.zip")
df_202007 = pd.read_csv("data\\202007-citibike-tripdata.csv.zip")

# %%
df_202008 = pd.read_csv("data\\202008-citibike-tripdata.csv.zip")
df_202009 = pd.read_csv("data\\202009-citibike-tripdata.csv.zip")
df_202010 = pd.read_csv("data\\202010-citibike-tripdata.csv.zip")
df_202011 = pd.read_csv("data\\202011-citibike-tripdata.csv.zip")
df_202012 = pd.read_csv("data\\202012-citibike-tripdata.csv.zip")

# %% [markdown]
# 2021/22

# %% [markdown]
# df_202101 = pd.read_csv("data\\202101-citibike-tripdata.csv.zip", low_memory=False)

# %% [markdown]
# df_202102 = pd.read_csv("data\\202102-citibike-tripdata.csv.zip", low_memory=False)
# df_202103 = pd.read_csv("data\\202103-citibike-tripdata.csv.zip", low_memory=False)
# df_202104 = pd.read_csv("data\\202104-citibike-tripdata.csv.zip", low_memory=False)

# %% [markdown]
# df_202105 = pd.read_csv("data\\202105-citibike-tripdata.csv.zip", low_memory=False)
# df_202106 = pd.read_csv("data\\202106-citibike-tripdata.csv.zip", low_memory=False)

# %% [markdown]
# df_202107 = pd.read_csv("data\\202107-citibike-tripdata.csv.zip", low_memory=False)
# df_202108 = pd.read_csv("data\\202108-citibike-tripdata.csv.zip", low_memory=False)
# df_202109 = pd.read_csv("data\\202109-citibike-tripdata.csv.zip", low_memory=False)

# %% [markdown]
# df_202110 = pd.read_csv("data\\202110-citibike-tripdata.csv.zip", low_memory=False)
# df_202111 = pd.read_csv("data\\202111-citibike-tripdata.csv.zip", low_memory=False)
# df_202112 = pd.read_csv("data\\202112-citibike-tripdata.csv.zip", low_memory=False)
# df_202201 = pd.read_csv("data\\202201-citibike-tripdata.csv.zip", low_memory=False)

# %%
#2019 for x in range 
print('done')
df_202102.info()

# %%
df_202101.info()

# %%
#df_202102
df_202102 = df.rename(columns={'started_at': 'starttime', 'ended_at': 'stoptime'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7776afd2d542> in <module>
#       1 #df_202102
# ----> 2 df_202102 = df.rename(columns={'started_at': 'starttime', 'ended_at': 'stoptime'})
#
# NameError: name 'df' is not defined

# %% [markdown]
# Concatinating the data frames before working on them

# %%
df02 = pd.DataFrame()
#frames = [df_202001,df_202002,df_202003,df_202004,df_202005,df_202006,df_202007,df_202008,df_202009,df_202010,df_202011,df_202012,df_202101,df_202102,df_202103,df_202104,df_202105,df_202106,df_202107,df_202108,df_202109,df_202110,df_202111,df_202112,df_202201]
].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %% [markdown]
# df_actual = [df_202101,df_202102,df_202103,df_202104]
# df_actual = pd.concat(df_actual)
# df_actual.to_csv('df_012021_042021.csv', index=False)
# df_actual.tail()
# seriesactual= df_actual.ride_id.groupby(pd.to_datetime(df_actual.started_at).dt.strftime('%Y-%m-%d %H')).count()
# dfact = pd.DataFrame({'date': seriesactual.index, 'count': seriesactual.values})
# dfact.tail()
# dfact.to_csv('timeseriesdata_actualtocompare.csv', index=False)

# %%
df02.starttime
# Out:
# 0          2020-01-01 00:00:55.3900
# 1          2020-01-01 00:01:08.1020
# 2          2020-01-01 00:01:42.1400
# 3          2020-01-01 00:01:45.5610
# 4          2020-01-01 00:01:45.7880
#                      ...
# 1088924    2020-12-31 23:58:21.7040
# 1088925    2020-12-31 23:58:37.8400
# 1088926    2020-12-31 23:58:52.8090
# 1088927    2020-12-31 23:59:55.9550
# 1088928    2020-12-31 23:59:57.4070
# Name: starttime, Length: 19506857, dtype: object

# %% [markdown]
# ## Hourly

# %%
#series = df02.usertype.groupby((pd.to_datetime(df02.starttime).dt.hour)).count()
series1 = df02.usertype.groupby(pd.to_datetime(df02.starttime).dt.strftime('%Y-%m-%d %H')).count()
#df['hour-date'] = df02.starttime, format='%Y-%m-%d %H').sum()

# %%
df = pd.DataFrame({'date': series1.index, 'count': series1.values})
df.head()
# Out:
#             date  count
# 0  2020-01-01 00    509
# 1  2020-01-01 01    633
# 2  2020-01-01 02    482
# 3  2020-01-01 03    260
# 4  2020-01-01 04    137

# %%
df.to_csv('timeseriesdata.csv', index=False)

# %% [markdown]
# ## Daily for weather

# %%
series2  = df02.usertype.groupby(pd.to_datetime(df02.starttime).dt.strftime('%Y-%m-%d')).count()
dfmonth = pd.DataFrame({'date': series2.index, 'count': series2.values})
dfmonth.to_csv('timeseriesdatamonth.csv', index=False)
dfmonth.head()
# Out:
#          date  count
# 0  2020-01-01  18114
# 1  2020-01-02  41556
# 2  2020-01-03  31873
# 3  2020-01-04  29436
# 4  2020-01-05  27589

# %%
dfmonth.shape
# Out:
# (366, 2)

# %% [markdown]
# # Prepare Data - 201901

# %% [markdown]
# ### error
# datatoexcel = pd.ExcelWriter('finaldata.xlsx') #write DataFrame to excel
# df.to_excel(datatoexcel) # save the excel
# datatoexcel.save()

# %% [markdown]
# ### Renaming the features

# %%
df02['starttime'] = pd.to_datetime(df02['starttime'])
df02['stoptime'] = pd.to_datetime(df02['stoptime'])
df02['start_hour'] = df02['starttime'].dt.hour.astype('category')
df02['start_day'] = df02['starttime'].dt.day.astype('category')

# %% [markdown]
# df['weekday'] = df['starttime'].dt.weekday.astype('category')
# df['weekend'] = [ d >=5 for d in df['weekday']]
# df.weekday.unique()

# %%
df.weekend.unique()
df.starttime.unique()

# %%
df02.resample('H', on='starttime')

# %%
df['start station id'].head()

# %% [markdown]
# Converting

# %%
cols = ['start station name', 'end station name', 'bikeid', 'usertype', 'gender']
for col in cols:
    df[col] = df[col].astype('category')

# %%
df.info()

# %%
df1 = pd.DataFrame()
df1['tripminutes'] = df['tripduration'] // 60
#sns.displot(data=df1,x="tripminutes", bins=range(1,61), aspect=10/5)
#sns.countplot(data=df, x="start_hour")

# %%
per_hour = pd.value_counts(df['start_hour'])
rph_df = per_hour.to_frame()
rph_df.reset_index(inplace=True)
rph_df.rename(columns = {'index' : 'time', 'start_hour' : 'rides'},inplace=True)


dfts = df.groupby(["start_hour", "start_hour"]).size().reset_index(name="Time")

# %%
df.tail()

# %%
tsdf = pd.DataFrame()
tsdf = df.assign(Date=df.starttime.dt.round('H'))

# %%
df_202105.info()

# %%
df_202201.info()
